# %% [markdown]
# <a href="https://colab.research.google.com/github/Gustavo7890/Machine-learning/blob/main/binariza%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow

# %%
import cv2

imagem = cv2.imread("/content/cachorro-docil.jpg")
gray_image = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY)

cv2_imshow(imagem)
cv2_imshow(gray_image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=800x531>
# <PIL.Image.Image image mode=L size=800x531>
# -1

# %%
imagem = cv2.imread("/content/cachorro-docil.jpg")
gray_image = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY)
threshold, image_binary = cv2.threshold(gray_image,128,255,cv2.THRESH_BINARY)

cv2_imshow(imagem)
cv2_imshow(image_binary)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=800x531>
# <PIL.Image.Image image mode=L size=800x531>
# -1
